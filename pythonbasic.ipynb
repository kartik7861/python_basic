# %%
# explain the key features of Python that make it a popular choice for programming?

#ANS 1.) Python is a programming language that is easy to understand and write and improves code readability for all the developers.
       #  2.) one of the main feactures of python is that it has a rich standard library that provides modules and packages for various programming needs.
       #  3.) In python code is executed line by line making debugging easier.
       #  4.) It is compatible with various programming paradigms such as object oriented , functional programming .

# %%
#Describe the role of predefined keywords in Python and provide examples of how they are used in a program? 
# predefined keywords are reserved words that have special meaning in the python language and they cannot be used as identifier (like variable name function name).
#Example of pre defined keywords include else , elif , if ,TRUE , FALSE , for , while , class etc.

# code example using if else 
x=11

if x> 10 :
    print ("x is greater than 10")
elif  x == 10 :
    print ("x is equal to 10") 
    
else :
    print ("x is less than 10")

    
    
# code exapmle using while loop     
i= 1

while i < 5 :
    
    j= 0   
    while  j < i :
        print ("*" , end ="")
        j += 1 
        
    print ()
        
    i += 1

# %%
#Compare and contrast mutable and immutable objects in Python with examples ?

# mutables objects in python are objects that can be changed or modified after they are created such as lists and dictionaries.
 
    
    # example of mutability using list 
    
new_list = [1,2,6,2.5,"kartik"]

new_list[4] = "ishita"    #modifying the list by changing element with another element 

new_list


# immutable objects in python are objects that cannot be changed or modified once created such as tuple string .
    
    #example of immutability using string 
    
b= "mbachaiwala"

b[0] = b  # here you will get an error as item assignment in string is not supported and you can't change m with b.

# %%
#Discuss the different types of operators in Python and provide examples of how they are used?
 # python support several types of operator 

    #Arithmetic operators - are used to perform mathematical operations like addition subtraction multiplication etc.
          # example 
     
p = 3
g = 5 

print (p + g)
print (p - g)
print (p * g)
print (p / g)

    #Comparison operators - are used to compare two values and return true and false 
                #example
l = 5
k = 6

print (l == k)
print (l != k)
print (l > k)
print (l < k)
    
    
    #Assignment operator - are used to assign value to a variable
           #example 
        
u = 7
v= 4

u+=4   #equivalent to u = u+4 

v*=3   #equivalent to v = v*3


    #logical operator - are used to combine conditional statements like & , or , not 
    
                  # example 
a= 1 
b = 0
print ( a & b) 
print ( a or b) 

    #bitwise operator - performs operations on bits

# %%
#Explain the concept of type casting in Python with examples ?

#type casting is the process of changing one data type into another in python 
#there are two type of type casting in python 1.implicit type casting 2.explicit type casting 
          # implicit type casting - the changing of data type is performed automatically by the python interpreter 
                       #example 

x=5     #type integer
y=5.5   #type float
print (x + y)  #here the x type is automatically converted into float 

          # explicit type casting- the conversion of data type is performed manually by the programmer using inbuit functions 
                       #example 

u="456"   #type is string str
x = int(u)       # here the type of u is converted from str to integer by using int function.
print(type(x))

# %%
#How do conditional statements work in Python ? Illustrate with examples ? 

#conditional statement in pythons are used to execute code based on evaluation of one or more conditions such as if , elif , else .

        #example using if elif and else 
    
age = 17
 
if age>=18 :
    print ("you are eligible to drive with a driving licence")
elif 16<age< 18 :
    print ("you are eligible to drive with a learning driving licence") 
else :
    print ("you are not eligible to drive")

# %%
# Describe the different types of loops in Python and their use cases with examples?
    # loops are used to execute a block of code repeatedly under some conditions. there are two primary types of loops
    #for loop
    #while loop  
           
          #exapmle of for loop 
            
for i in range(6):              #range6 genrates number from 0 to 6and for loop print each number one by one 
    print (i)
    
    #while loop repeated execute a block of code as long as given condition is true 
        #example of while loop 
        
num= 1
while num<5 :  # while loop will run as long as num is smaller than 5 
    print ("*")
    num +=1         # the num variable is incremented by 1 afer every sucessfull execution
